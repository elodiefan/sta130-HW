# %% [markdown]
# # Pre-Lecture HW

# %%
from IPython.display import YouTubeVideo
# First pre-lecture video: 
# "Hypothesis testing. Null vs alternative
# https://www.youtube.com/watch?v=ZzeXCKd5a18
YouTubeVideo('ZzeXCKd5a18', width=800, height=500)

# %%
from IPython.display import YouTubeVideo
# Second pre-lecture video
# "What is a p-value"
# https://www.youtube.com/watch?v=9jW9G8MO4PQ
YouTubeVideo('9jW9G8MO4PQ', width=800, height=500)

# %% [markdown]
# ## Question 1

# %% [markdown]
# **Hypothesis Testing, Null Hypothesis, and Alternative Hypothesis**
#
# - The key factor differentiating testable and untestable ideas statistically is the ability to frame the idea as a statement about a population parameter that can be quantified and measured. For instance, you can test the idea "people are taller now than they were 50 years ago" because you can compare average heights of populations at different times. You cannot, however, test the idea "cats are funnier than dogs" because "funniness" is not something that can be objectively quantified and measured across populations.
# - A good null hypothesis (often denoted as H0) should meet these criteria:
#     - It's a statement about a population parameter.
#     - It posits no effect or no difference.
#     - It can be contradicted by evidence found in the data.
#     - It's testable, meaning data can be collected and analyzed to assess its validity.
# - In hypothesis testing, you contrast two competing hypotheses:
#     - Null Hypothesis (* H0): This is the statement you're trying to disprove. It assumes the effect you're interested in doesn't exist in the population. For instance, if you were testing whether a new drug lowers blood pressure, the null hypothesis might be "the new drug has no effect on blood pressure."
#     - Alternative Hypothesis (* HA): This is the statement you're trying to find evidence for. It proposes that there is an effect. In the drug example, the alternative hypothesis would be "the new drug does have an effect on blood pressure."

# %% [markdown]
# **Summary of the NotebookLM Session (no link to the transcript)**
#
# Chatbot Session Summary
#
# You initially asked about **hypothesis testing, null hypothesis, and alternative hypothesis**, specifically:
#
# * What is the key factor that makes some ideas testable statistically while others are not?
# * What are the criteria for a good null hypothesis?
# * What is the difference between a null hypothesis and an alternative hypothesis in the context of hypothesis testing?
#
# My initial response, based on the source you provided, was that the source did not contain information about these topics. I then attempted to answer your question using general knowledge, without relying on your provided sources.
#
# To create a more comprehensive and insightful summary for your homework assignment, please provide the "first pre-lecture video" mentioned in your initial query, or other sources that contain relevant information to your questions.

# %% [markdown]
# ## Question 2

# %% [markdown]
# **Distinguishing Between Sample Statistics and Population Parameters in Hypothesis Testing**
#
# **For a non-statistical audience:**
# - $x_i$: This represents a single observation or data point in a sample. For instance, if we are trying to measure the height of students in a class, each student's height would be an $x_i$.
# - $\bar{x}$ (x-bar): This is the sample mean, calculated by averaging all the $x_i$ values in the sample. It gives an estimate of the central tendency of the sample data.
# - $\mu$ (mu): This is the population mean, which is the true average value of the variable of interest for the entire population. This is usually unknown and it is what we are trying to learn about through hypothesis testing.
# - $\mu_0$ (mu-zero): This is the hypothesized population mean, which is a specific value we are testing against in our hypothesis test. For example, we might test if the average height of students in a school ($\mu$) is equal to a hypothesized value, $\mu_0$ = 5'8".
#
#
# - When we perform a hypothesis test, we are using the information from our sample (the $x_i$'s and $\bar{x}$) to make an inference about the population parameter, $\mu$. The result of the hypothesis test (whether we reject or fail to reject the null hypothesis) tells us something about the plausibility of $\mu_0$ being the true population mean, $\mu$. We are not directly testing the sample mean, $\bar{x}$ , it is simply a tool we use to reach a conclusion about the population.
# - Overall speaking, hypothesis testing allows us to use limited sample data to make informed statements about the larger population from which the sample was drawn.

# %% [markdown]
# In more simple terms:
#
#
# - The Big Picture (Population): If let's say you're interested in the average height of all students in a school. The "population" is the entire group of students, and the "population parameter" is the average height of everyone in this group, represented by μ in statistical notation.
# - The Snapshot (Sample): Since it is impractical to measure every student's height, you can take a smaller group of students, which is a "sample," and measure their heights. These individual measurements from your sample are your $x_i$'s.
# - Estimating from the Snapshot (Sample Mean): You can calculate the average height of your sample, which is the "sample mean" represented by $\bar{x}$. This sample mean is a "statistic," meaning it is a value calculated from your sample data.
# - Hypothesis Testing: Make an educated guess about the Big Picture: The goal of hypothesis testing is to use the information from your sample (the snapshot) to make an educated guess about the population (the big picture).
#     - You start with an assumption about the population mean called the null hypothesis ($H_0$). For example, you might assume the average height of all students in the school is 5'8'' ($\mu_0$).
#     - You then see if the data from your sample provides enough evidence to reject this null hypothesis. This doesn't mean proving the null hypothesis is definitively false; it means determining if your sample data is unlikely to occur if the null hypothesis were actually true for the entire population.
# - The Result is About the Big Picture (Population): The outcome of your hypothesis test isn't telling you for sure whether the average height of your specific sample ($\bar{x}$) is equal to, greater than, or less than 5'8". Instead, it's giving you a level of confidence about whether the true average height of the entire school population (μ) is likely to be 5'8", based on the evidence you gathered from your sample.

# %% [markdown]
# **Summary of the NotebookLM Session (no link to the transcript)**
#
# This conversation focused on clarifying the distinction between sample statistics and population parameters in the context of hypothesis testing. You specifically asked for an explanation of the following statement from source: "It is important to note that outcomes of tests refer to the population parameter, rather than the sample statistic! As such, the result that we get is for the population."
#
# The initial responses used the statistical notations  $x_i$ (individual observation), $\bar{x}$ (sample mean), $\mu$ (population mean), and $\mu_0$ (hypothesized population mean) to break down the concept.  The explanation highlighted that hypothesis testing uses sample data (like a sample mean) to draw conclusions about the larger population from which the sample originated.
#
# You then requested a simpler explanation suitable for a "non-statistical audience." The subsequent response continued to use the student height example, but simplified the language further. It emphasized:
#
# *   **The difference between a population and a sample:** The population is the entire group of interest (all students in a school), while a sample is a smaller, manageable subset of that group.
# *   **The role of the sample mean:** The sample mean is an estimate calculated from the sample data, used to make inferences about the unknown population mean.
# *   **The purpose of hypothesis testing:** Hypothesis testing provides a framework for using the sample evidence to assess the plausibility of an assumption (null hypothesis) about the population.
# *   **The interpretation of the test result:** The outcome of the hypothesis test doesn't give a definitive answer about the sample mean. Instead, it tells us how likely the assumed population mean is, given the observed sample data.
#
# The conversation aimed to clarify that while we work with sample statistics in hypothesis testing, the ultimate goal is to understand and make inferences about the population parameter.

# %% [markdown]
# ## Question 3

# %% [markdown]
# **Why Imagine a World Where the Null Hypothesis is True?**
#
# The second "Pre-lecture" video explains that when calculating a p-value, we "imagine a world where the null hypothesis is true" because we are trying to determine how likely it is to observe our data, or data even more extreme, if the null hypothesis was actually true.
#
# *   This is where the **sampling distribution of the test statistic under the null hypothesis** becomes important.
# *   The **sampling distribution** refers to the distribution of test statistics we would obtain if we were to repeatedly sample from the population under the assumption that the null hypothesis is true.
# *   We can think about simulating this by, for example, flipping a coin many times if our null hypothesis is that the coin is fair.
#
# Essentially, the **p-value** represents how likely it would be to observe a test statistic as extreme as the one we actually calculated (or even more extreme), if we were to live in a world where the null hypothesis is true.
#
# * A small p-value tells us that it would be very unlikely to observe our data if the null hypothesis was true, suggesting the null hypothesis is likely false. Conversely, a large p-value doesn't necessarily prove the null hypothesis true, but merely indicates a lack of evidence to reject it.

# %% [markdown]
# **Summary of the NotebookLM Session (no link to the transcript)**
#
# Chatbot Session Summary: Understanding p-values and the Null Hypothesis
#
# You asked me to explain why, when calculating a p-value, we "imagine a world where the null hypothesis is true" [Source 3, Section 3].
#
# I explained that this is because we're trying to see how likely our data would be if the null hypothesis was actually true. I highlighted the importance of the **sampling distribution of the test statistic under the null hypothesis**. This distribution shows the different test statistics we'd get if we took repeated samples from a population where the null hypothesis is true.
#
# You can think of it like flipping a coin many times to test if it's fair. If the null hypothesis is that the coin is fair, the sampling distribution would show the range of results you'd expect to see over many sets of flips (e.g., how often you'd get 6 heads out of 10 flips, 7 heads, etc.).
#
# The **p-value**, then, tells us how likely it is to get a test statistic as extreme as, or even more extreme than, the one we actually observed, *if* the null hypothesis were true. A small p-value suggests the null hypothesis is probably false because our data would be unusual in a world where the null is true.  A large p-value just means we don't have enough evidence to reject the null hypothesis, not necessarily that the null hypothesis is true.

# %% [markdown]
# ## Question 4

# %% [markdown]
# A smaller p-value makes the null hypothesis look "more ridiculous" because it means that the observed test statistic is very unlikely to have occurred if the null hypothesis were true.
#
# * **The p-value is calculated by assuming the null hypothesis is true.** This means we're essentially "imagining a world" where the null hypothesis holds.
# * **In this imagined world, we look at how often we would expect to see a test statistic as extreme as the one we actually observed.**  This expectation is based on the sampling distribution of the test statistic under the null hypothesis.
# * **A small p-value means that, if the null hypothesis were true, it would be very rare to observe a test statistic as extreme as ours.**  For example, a p-value of 0.01 means that only 1% of the time would we expect to see such an extreme test statistic under the null hypothesis.
# * **Therefore, a small p-value suggests that our observed data is quite surprising if the null hypothesis were actually true.**  It's like flipping a coin 100 times and getting heads 95 times - this outcome is so unlikely under the assumption of a fair coin (our null hypothesis) that we start to question if the coin is actually fair.
#
# In essence, the smaller the p-value, the further out on the "tails" of the sampling distribution our observed test statistic lies, making it more and more improbable under the assumption that the null hypothesis is true.  This increasing improbability is what makes the null hypothesis look "more ridiculous" as the p-value shrinks.

# %% [markdown]
# **Summary of the NotebookLM Session (no link to the transcript)**
#
# This conversation focused on understanding why a smaller p-value makes a null hypothesis "look more ridiculous," as explained in the second pre-lecture video referenced in the source.
#
# *   You accurately described how a smaller p-value implies that the observed test statistic is less likely to occur if the null hypothesis were true.
# *   You explained that a small p-value suggests the observed data is surprising if the null hypothesis were true.
# *   You drew an analogy to flipping a coin many times and getting a disproportionate number of heads, leading one to question the fairness of the coin. This example effectively illustrates how a low p-value challenges the assumed truth of the null hypothesis.
# *   You correctly stated that the smaller the p-value, the further the observed test statistic lies on the "tails" of the sampling distribution, thus making it less probable under the null hypothesis.
#
# The conversation successfully clarified the relationship between smaller p-values and the increasing implausibility of the null hypothesis. Your explanation effectively incorporated the concepts of the sampling distribution, observed test statistics, and the idea of "imagining a world" where the null hypothesis holds true to explain why a smaller p-value casts more doubt on the null hypothesis.

# %% [markdown]
# ## Question 5

# %% [markdown]
# **Simulating a p-value for Head Tilting While Kissing**
#
# *   In this scenario, you can think of the 124 couples as your **sample** from the larger **population** of humans who kiss.
# *   Each individual $x_i$ represents whether a couple tilted their head to the right ($x_i=1$) or to the left ($x_i=0$) when kissing.
# *   The **sample statistic** $\bar{x}$ is the observed proportion of couples who tilted their heads to the right (64.5%).
# *   The **null hypothesis** ($H_0$) states that there is no preference for left or right head tilting in the population, meaning the true proportion (μ) is 50%.
# *   You're asked to simulate a **p-value** using a coin flip model to represent this null hypothesis, where heads represents a rightward tilt.
#
# **Imagining a World Where the Null Hypothesis is True**
#
# *   To "imagine a world where the null hypothesis is true" means to consider a scenario where there's no real head-tilting preference when kissing.
# *   In this scenario, observing 64.5% of couples tilting their heads to the right would be purely by chance, like flipping a coin and getting heads 64.5% of the time.
#
# **Calculating the p-value**
#
# *   To calculate the p-value, you would simulate numerous coin flips (representing couples kissing) with a 50/50 probability (representing the null hypothesis).
# *   For each simulation, you'd record the proportion of "heads" (rightward tilts).
# *   The p-value would be the proportion of simulations where the proportion of "heads" is as extreme as, or more extreme than, the observed 64.5%.
# *   This p-value represents the probability of observing data as extreme as yours (or even more extreme) if the null hypothesis of no real head-tilting preference were actually true.
#
# **Determining the Level of Evidence**
#
# *   Finally, you would compare the simulated p-value to the "strength of evidence" table provided.
# *   This will tell you whether your data provides "no evidence," "weak evidence," "moderate evidence," "strong evidence," or "very strong evidence" against the null hypothesis.
# *   Remember, a smaller p-value suggests the observed data is less likely to occur under the null hypothesis, providing stronger evidence against it.
#
# This systematic approach allows you to statistically assess whether the observed head-tilting preference in your sample provides enough evidence to conclude that a similar preference exists in the larger population of kissing couples.

# %% [markdown]
# **Summary of the NotebookLM Session (no link to the transcript)**
#
# Here is a summary of the chatbot session, as requested:
#
# *   You asked the chatbot to simulate a p-value for a scenario from Güntürkün (2003), where 80 out of 124 kissing couples tilted their heads to the right. You wanted to use a "50/50 coin-flipping" model to represent the null hypothesis that there's no preference for head tilting direction in the population.
# *   The chatbot responded by outlining how to approach the simulation. It broke down the problem in terms of **sample**, **population**, $x_i$'s, **sample statistic** ($\bar{x}$), and the **null hypothesis** ($H_0$).
# *   It then explained that "imagining a world where the null hypothesis is true" means considering a scenario where the observed 64.5% rightward head tilt is purely due to chance, like getting heads that often in a series of coin flips.
# *   The chatbot then outlined the steps for calculating the p-value: simulating numerous coin flips, recording the proportion of "heads" for each simulation, and calculating the proportion of simulations with results as extreme as, or more extreme than, the observed 64.5%.
# *   Finally, it explained how to interpret the simulated p-value using a "strength of evidence" table to determine the level of evidence against the null hypothesis. It emphasized that a smaller p-value suggests stronger evidence against the null hypothesis.
#
# In essence, the chatbot provided a framework for statistically assessing whether the observed head-tilting preference in the sample of kissing couples from Güntürkün (2003) provides enough evidence to reject the null hypothesis of no preference in the larger population.

# %% [markdown]
# ## Question 6

# %% [markdown]
# **Can a p-value definitively prove anything?**
#
# **No, a smaller p-value cannot definitively prove that the null hypothesis is false.  It can only provide stronger evidence against it.** Similarly, **we cannot definitively prove Fido's innocence or guilt using a p-value.**
#
# Here's why:
#
# * **Hypothesis testing is about evidence, not proof.** A p-value helps us understand the likelihood of observing our data if the null hypothesis were true. A small p-value suggests that our data would be unlikely if the null hypothesis were true, leading us to reject the null hypothesis. However, it doesn't "prove" the alternative hypothesis is true.
# * **There's always a chance of error.** We could obtain a small p-value by chance, even if the null hypothesis were true (a Type I error).  Conversely, we could fail to reject the null hypothesis even if it were false (a Type II error).
# * **The p-value depends on the null hypothesis and its assumptions.** The p-value is calculated based on the assumption that the null hypothesis is true. If the null hypothesis is poorly defined or its assumptions are violated, the p-value may be misleading.
#
# **Rather than seeking definitive proof, we use p-values and hypothesis testing to make informed decisions based on the strength of the evidence.**  A smaller p-value provides stronger evidence against the null hypothesis, but it never completely rules out the possibility that the null hypothesis could be true.

# %% [markdown]
# **Summary of the NotebookLM Session (no link to the transcript)**
#
# Here is a summary of our interaction, combining information from our conversation with the provided source material:
#
# *   You asked if a smaller p-value could definitively prove a null hypothesis false, and if a p-value could be used to definitively prove whether or not Fido (from a video mentioned in the source material) was guilty. [You]
# *   The response summarized our earlier conversation, which concluded that a smaller p-value cannot definitively prove that a null hypothesis is false. [You]
# *   **A smaller p-value only provides stronger evidence against a null hypothesis.** [You, 32, 33, 34]
# *   You were reminded that **hypothesis testing is about providing evidence, not proof.** [You]
# *   The response reiterated that there is always a chance for error in hypothesis testing, as we could obtain a small p-value by chance (Type I error) or fail to reject a null hypothesis that is false (Type II error). [You, 35, 36]
# *   Furthermore, the response explained that **p-values are calculated based on the assumption that the null hypothesis is true, and if that assumption is flawed, the p-value will be misleading.** [You]
# *   Finally, you were reminded that **we use p-values and hypothesis testing to make informed decisions based on the strength of evidence, not to make definitive claims.** [You]
#
# The sources discuss p-values in the context of a larger discussion about hypothesis testing. The concept of a null hypothesis is introduced in the context of determining whether or not an idea can be tested statistically. You should understand the key criteria for a good null hypothesis and the difference between a null hypothesis and an alternative hypothesis.
#
# The sources note, as our conversation did, that p-values and hypothesis testing are not about proof, but about providing evidence. [You, 35, 36] One of the sources provides a table to help interpret p-values:
#
# | p-value           | Evidence                                                      |
# | :---------------- | :----------------------------------------------------------- |
# |  $$p > 0.1$$       | No evidence against the null hypothesis                     |
# | $$0.1 \ge p > 0.05$$ | Weak evidence against the null hypothesis                     |
# | $$0.05 \ge p > 0.01$$ | Moderate evidence against the null hypothesis                  |
# | $$0.01 \ge p > 0.001$$ | Strong evidence against the null hypothesis                  |
# | $$0.001 \ge p$$      | Very strong evidence against the null hypothesis              |
#
# Keep in mind that this table should not be taken as definitive proof, but rather as a helpful guide for interpreting the strength of evidence against a null hypothesis.

# %% [markdown]
# # Post-Lecture HW

# %% [markdown]
# ## Question 7

# %% [markdown]
# To answer your question about one-tailed vs. two-tailed hypothesis tests and how to adjust code for a one-tailed test, you would need to provide the code from "Demo II of the Week 5 TUT" and the "Vaccine Data Analysis Assignment" from Week 04 HW "Question 8". The provided source, "STA130F24_HW05_DueOct10.md," mentions these resources but does not contain the code itself.
#
# However, I can explain the general concept of one-tailed vs. two-tailed tests and how the interpretation of the p-value changes:
#
# * **Two-tailed test:** This type of test examines whether the sample mean is significantly different from the hypothesized population mean (µ0) in *either direction*. The alternative hypothesis (HA) for a two-tailed test is simply that µ ≠ µ0.
# * **One-tailed test:** This type of test is more specific and examines whether the sample mean is significantly *greater than* or *less than* the hypothesized population mean, but not both.  There are two types of one-tailed tests:
#     * **Right-tailed test:** HA: µ > µ0
#     * **Left-tailed test:** HA: µ < µ0
#
# **Changes in Code and Interpretation**
#
# The main difference in the code for a one-tailed test lies in how the p-value is calculated. In a two-tailed test, you would typically count the number of times the simulated test statistic is as extreme as or more extreme than the observed test statistic in *both* tails of the distribution. For a one-tailed test, you would only consider one tail of the distribution, depending on the direction specified in your alternative hypothesis.
#
# **Smaller p-value in one-tailed test:**
#
# Yes, we generally expect the p-value to be smaller in a one-tailed test compared to a two-tailed test for the same data. This is because you are only considering the probability of observing the data in one tail of the distribution, making it easier to reject the null hypothesis if the effect is in the direction you specified.
#
# **Important Considerations When Choosing a One-Tailed Test:**
#
# * You should have a strong justification for focusing on only one direction of the effect.
# * Choosing a one-tailed test after observing the data can lead to biased results.
#
# Remember that without the actual code from "Demo II," I cannot provide specific changes. However, I hope this general explanation is helpful!

# %% [markdown]
# **Summary of the NotebookLM Session (no link to the transcript)**
#
# This conversation focused on your question about the difference between one-tailed and two-tailed hypothesis tests, and how to adjust code for a one-tailed test. You specifically asked about how to modify the code from "Demo II of the Week 5 TUT" and the "Vaccine Data Analysis Assignment" from Week 04.  You also asked whether we should expect the p-value to be smaller in a one-tailed versus a two-tailed analysis.
#
# It was noted that the provided source, "STA130F24_HW05_DueOct10.md," mentions these resources but doesn't contain the code itself. Therefore, specific code changes could not be provided.
#
# However, a general explanation of one-tailed vs. two-tailed tests was given, including how the interpretation of the p-value changes:
#
# *   **Two-tailed test:** Examines if the sample mean is significantly different from the hypothesized population mean in *either direction* (µ ≠ µ0)
# *   **One-tailed test:**  Examines if the sample mean is significantly *greater than* or *less than* the hypothesized population mean, but not both.
#     *   **Right-tailed test:** µ > µ0
#     *   **Left-tailed test:** µ < µ0
#
# The response explained that the main difference in code for a one-tailed test is in how the p-value is calculated. In a two-tailed test, you count how many times the simulated test statistic is as extreme or more extreme than the observed test statistic in *both* tails. For a one-tailed test, you only consider **one tail** based on the direction in your alternative hypothesis.
#
# Finally, it was stated that we generally expect a **smaller p-value in a one-tailed test** compared to a two-tailed test for the same data. This is because you're only considering the probability of observing the data in one tail, making it easier to reject the null hypothesis if the effect is in your specified direction.

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### **Problem Introduction**
#
# This analysis is inspired by the famous Fisher's Tea Experiment, where Dr. Muriel Bristol claimed she could taste whether milk was added before or after tea. Fisher, skeptical of this claim, proposed a hypothesis test. In our adaptation of this experiment, we examine whether students in STA130 can correctly identify if milk or tea was poured first in a single cup of tea. Out of 80 students, 49 correctly identified the pouring order.
#
# ### **Relationship Between This Experiment and the Original**
#
# The key differences between the STA130 experiment and Fisher’s original experiment are:
#
# 1. Sample Size: Fisher's original test involved only 8 cups, while this experiment involves 80 students, each tasting one cup.
# 2. Population: Dr. Bristol, the subject of the original experiment, had a personal claim about her ability to distinguish the order of pouring. In this context, the STA130 students are a more general population, with no prior claim about their ability to distinguish the order.

# %% [markdown]
# ### **Null and Alternative Hypotheses**
#
# **Null Hypothesis (H₀)**
# **Formal Statement:** The students are randomly guessing, i.e., the probability that a student correctly identifies whether milk or tea was poured first is 0.5.
#
# **Mathematical Form:**
#
# $H_0$: 𝑝 = 0.5
# where 𝑝 is the population proportion of students who can correctly identify the pouring order.
#
# **Informal Statement:** The students are just guessing, and their chance of being correct is 50%.
#
# **Alternative Hypothesis (H₁)**
# **Formal Statement:** The students are not randomly guessing; they have a better-than-chance ability to correctly identify the order of pouring.
#
# **Mathematical Form:**
# $H_1$: 𝑝 > 0.5
#
# **Informal Statement:** The students have some ability to correctly identify whether the milk or tea was poured first, better than just random guessing.

# %% [markdown]
# ### **Quantitative Analysis**
#
# **Observed Data**
# - Sample Size (𝑛): 80 students
# - Correct Responses: 49 students
# - Sample Proportion ($\hat{p}$):
# $\hat{p}$ = 49/80 = 0.6125
# We want to assess whether this sample proportion is significantly greater than 0.5.
#
# **Methodology**
# We will conduct a **hypothesis test for a population proportion** using the following steps:
#
# 1. **Assume H₀ is true**, which means the probability of a correct response is 0.5.
# 2. **Compute the test statistic**, which follows a normal distribution under the null hypothesis.
# The test statistic is given by:
#
# z = ($\hat{p}$ - $p_0$) / $\sqrt{((p_0)(1-p_0)) / n}$
#
# where:
# - $\hat{p}$ is the sample proportion (0.6125)
# - $p_0$ is the population proportion under the null hypothesis (0.5)
# - n is the sample size (80)
#
# 3. **Estimate the p-value** using the standard normal distribution.
# 4. **Draw conclusions** based on the p-value.

# %%
import numpy as np
from scipy.stats import norm

# Set seed for reproducibility
np.random.seed(130)

# Given data
n = 80  # sample size
correct_responses = 49  # number of correct responses
p_hat = correct_responses / n  # sample proportion
p_0 = 0.5  # null hypothesis proportion

# Calculate the z-score (test statistic)
z = (p_hat - p_0) / np.sqrt((p_0 * (1 - p_0)) / n)

# Calculate the p-value
p_value = 1 - norm.cdf(z)  # One-tailed test

# Output results
z, p_value
# Out:
# (2.0124611797498115, 0.022085672454221217)

# %% [markdown]
# This will compute the z-score and the p-value, which we will interpret to assess whether we reject or fail to reject the null hypothesis.

# %% [markdown]
# **Supporting Visualizations (Optional)**
#
# We can simulate the sampling distribution of the proportion under the null hypothesis to visually compare the observed sample proportion to the distribution.

# %%
import matplotlib.pyplot as plt

# Simulate random guessing under the null hypothesis
simulated_proportions = np.random.binomial(n, p_0, 10000) / n

# Plot the distribution
plt.hist(simulated_proportions, bins=30, edgecolor='k', alpha=0.7)
plt.axvline(p_hat, color='red', linestyle='dashed', label=f'Observed p = {p_hat}')
plt.title('Sampling Distribution of Proportion (Under H₀)')
plt.xlabel('Proportion Correct')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# ### **Findings and Discussion**
# - **Test Statistic (z-score):** The computed z-score helps quantify how far the observed proportion (0.6125) is from the expected proportion under the null hypothesis (0.5).
# - **p-value:** The p-value indicates the probability of obtaining a sample proportion as extreme as 0.6125, assuming the null hypothesis is true. A low p-value suggests that the observed result is unlikely under the null hypothesis.
#
# ### **Conclusion Regarding the Null Hypothesis**
# If the p-value is smaller than the significance level (e.g., α=0.05), we reject the null hypothesis, indicating that the STA130 students' ability to distinguish the order of pouring is unlikely due to random guessing. Conversely, if the p-value is greater than 𝛼, we fail to reject the null hypothesis, implying that the result could plausibly be due to chance.
#
# In our case, based on the z-score and p-value, we will make a formal conclusion about whether the students have a better-than-chance ability to detect the correct pouring order.

# %% [markdown]
# ### **Formal Conclusion**
#
# Given that the p-value is 0.0221, which is less than the typical significance level of 𝛼 = 0.05, **we reject** the null hypothesis. This means that there is sufficient evidence to suggest that the STA130 students have a better-than-chance ability to correctly identify whether tea or milk was poured first. The observed result (49 out of 80 correct identifications) is unlikely to be due to random guessing alone.

# %% [markdown]
# ### Binomtest

# %%
from scipy.stats import binomtest

# Given data
n = 80  # sample size
correct_responses = 49  # number of correct responses
p_0 = 0.5  # null hypothesis proportion

# Perform the binomial test using binomtest
result = binomtest(correct_responses, n, p_0, alternative='greater')

# Extract the p-value
p_value_binom = result.pvalue

p_value_binom
# Out:
# 0.028332213172560572

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# Given data
n = 80  # number of trials (students)
p_0 = 0.5  # probability of success under the null hypothesis
correct_responses = 49  # observed correct responses

# Generate binomial distribution
x = np.arange(0, n + 1)  # possible number of correct responses (0 to 80)
pmf = binom.pmf(x, n, p_0)  # probability mass function for binomial distribution

# Plot the binomial distribution
plt.figure(figsize=(10, 6))
plt.bar(x, pmf, color='lightblue', label='Binomial Distribution (n=80, p=0.5)', alpha=0.7)

# Highlight the observed value and tail beyond 49
plt.bar(x[correct_responses:], pmf[correct_responses:], color='red', alpha=0.7, label=f"Observed (49 and beyond)")

# Add labels and title
plt.axvline(correct_responses, color='black', linestyle='--', label=f'Observed = {correct_responses}')
plt.xlabel('Number of Correct Responses')
plt.ylabel('Probability')
plt.title('Binomial Distribution Under Null Hypothesis (p = 0.5)\nObserved Value: 49 Correct Responses')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ### Formal Conclusion (with p-value = 0.0283):
# Since the p-value is 0.0283, which is still less than the typical significance level of α=0.05, **we reject** the null hypothesis. This means that there is sufficient evidence to suggest that the STA130 students are better than random guessing at identifying whether tea or milk was poured first. The observed result is unlikely to have occurred purely by chance.

# %% [markdown]
# **[Link to the ChatBot Session](https://chatgpt.com/share/670da819-bc4c-800e-8dc9-38870403b08c)**
#
# **Summary of the ChatBot Session**
#
# In this chatbot session, you sought assistance for your assignment related to Fisher's Tea Experiment, specifically focusing on the analysis of 49 out of 80 STA130 students correctly identifying whether tea or milk was poured first. Here's a summary of our exchanges:
#
# Hypothesis Testing:
#
# We began by discussing how to test whether the results could be attributed to chance (random guessing).
# I helped you calculate the z-score and p-value using a normal approximation and concluded that the p-value of 0.0221 was significant, leading to the rejection of the null hypothesis.
# Binomial Test:
#
# You requested a more accurate analysis using the binomial test. I introduced the binomtest function from scipy.stats and explained that the p-value, when using this method, was 0.0283.
# Based on this p-value, we concluded that the result was still statistically significant, and the null hypothesis (random guessing) was rejected.
# Visualization:
#
# You asked for a visualization of the binomial test, and I provided Python code to plot the binomial probability distribution for 80 trials with $𝑝_0$ =0.5. The plot highlighted the observed value (49 correct responses) and the corresponding tail of the distribution to visually represent the p-value.
# Throughout the session, I provided code snippets, explanations of hypothesis testing, and visualization to support your understanding and assist with your assignment.

# %% [markdown]
# ## Question 9

# %% [markdown]
# Yes.
